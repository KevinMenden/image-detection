# %%
import torch

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

data_path = "/run/media/kevin/Volume/OpenImages/"

# %%
# get file names
files = os.listdir(os.path.join(data_path, "pics"))
print(f"{len(files)} images downloaded")
image_ids = [x.replace(".jpg", "") for x in files]

# load class descriptions
# load class descriptions
cls = pd.read_csv(os.path.join(data_path, "class-descriptions-boxable.csv"), header=None, index_col=0)


# load image labels
labs = pd.read_csv(os.path.join(data_path, "train-annotations-human-imagelabels-boxable.csv"))
labs.head()

# filter labels for available pics
labs = labs[labs['ImageID'].isin(image_ids)]
print(len(set(labs['ImageID'])))
# Out:
# 796158 images downloaded
# 796158

# %%
len(set(labs['ImageID']))
labs.to_csv(os.path.join(data_path, "subset_train_annots.csv"))

# %%
idx = 2193
img_id = image_ids[idx]
print(img_id)
# load and show image
im = Image.open(os.path.join(data_path,"pics",files[idx]))
plt.imshow(im)


# get labels
tmp = labs.loc[[x == img_id for x in list(labs['ImageID'])]]
#tmp = tmp[tmp['Confidence'] == 1]
tmp_labels = list(set(tmp['LabelName']))
print(cls.loc[tmp_labels,:].iloc[:,0])
# Out:
# 001330501fce65ab
# 0
# /m/04rky         Mammal
# /m/01btn          Barge
# /m/0jbk          Animal
# /m/083wq          Wheel
# /m/019jd           Boat
# /m/01rzcn    Watercraft
# /m/0bt9lr           Dog
# /m/01lrl      Carnivore
# /m/07jdr          Train
# /m/07yv9        Vehicle
# Name: 1, dtype: object

# %%
labs.head()
# Out:
#             ImageID        Source  LabelName  Confidence
# 0  000002b66c9c498e  verification  /m/014j1m           0
# 1  000002b66c9c498e  verification  /m/014sv8           1
# 2  000002b66c9c498e  verification   /m/01599           0
# 3  000002b66c9c498e  verification   /m/015p6           0
# 4  000002b66c9c498e  verification  /m/015x4r           0

# %%
labels = labs.copy()
labels.index = labels['ImageID']
labels = labels[labels['Confidence'] == 1]
label_names = np.sort(list(set(labels['LabelName'])))
root_dir = os.path.join(data_path, "pics")

# %%
# Get and image using a index

idx = 123
images = list(set(labs['ImageID']))
img_id = images[idx]

# Get the image
img_path = os.path.join(root_dir, images[idx]+".jpg")
image = np.asarray(Image.open(img_path))
# Get the label
tmp = np.array(labels.loc[img_id,]['LabelName'])
tmp_labs = np.array([1 if x in tmp else 0 for x in label_names])
np.sum(tmp_labs)

image_label = tmp_labs

sample = {'image': image, 'label': image_label}
# Out:
# 6

# %%
class ImageDataset(Dataset):
    """Test Class"""
    
    def __init__(self, label_file, root_dir, transform=None):
        self.labels = pd.read_csv(label_file)
        self.root_dir = root_dir
        self.transform = transform
        
        # Make some adjustments
        self.labels.index = self.labels['ImageID']
        self.labels = self.labels[self.labels['Confidence'] == 1]
        self.label_names = np.sort(list(set(self.labels['LabelName'])))
        self.images = list(set(self.labels['ImageID']))
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        """ Get an image"""
        if torch.is_tensor(idx):
            idx = idx.tolist()
            
        # Load image
        img_path = os.path.join(self.root_dir, self.images[idx]+".jpg")
        image = np.asarray(Image.open(img_path))
        
        # Create label vector
        img_objects = np.array(self.labels.loc[img_id,]['LabelName'])
        image_label = np.array([1 if x in img_objects else 0 for x in self.label_names])
        
        sample = {'image': image, 'label': image_label}
        
        return sample

# %%
root_dir = os.path.join(data_path, "pics")
csv_path = os.path.join(data_path, "subset_train_annots.csv")

# %%
dataset = ImageDataset(label_file = csv_path, root_dir = root_dir)

# %%
len(dataset)
# Out:
# 796158

# %%
for i in range(5):
    sample = dataset[i]
    img = sample['image']
    plt.imshow(img)
